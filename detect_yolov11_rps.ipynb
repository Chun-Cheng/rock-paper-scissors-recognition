# %%
# install dependencies
# !uv sync --all-extras

# %%
from IPython.display import Image

# %%
# 指定推論的圖片與模型路徑
image_path = 'images/s.jpeg'
weights_path = 'runs/detect/train/weights/best.pt'

# %%
from ultralytics import YOLO

# Load a COCO-pretrained YOLO11n model
model = YOLO(weights_path)

# %%
results = model(image_path)

# Process results list
for result in results:
    boxes = result.boxes  # Boxes object for bounding box outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
    obb = result.obb  # Oriented boxes object for OBB outputs
    # result.show()  # display to screen
    result.save(filename="result.jpg")  # save to disk
    display(Image(filename='result.jpg', width=320))
# Out:
# image 1/1 /Users/cheng/Projects/school/machine_learning/final/images/s.jpeg: 640x480 1 Scissors, 41.6ms
# Speed: 1.9ms preprocess, 41.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 480)
